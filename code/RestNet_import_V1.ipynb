# %%
from fastai import *
from fastai.vision import *

# %%
model_inf = load_learner('/content/drive/My Drive/Clasificacion-Pistas/')

# %%
img = open_image('/content/drive/My Drive/Clasificacion-Pistas/cinco.png')
print(model_inf.predict(img)[0])
img
# Out:
# Positivo-Drive
# Image (3, 194, 192)
